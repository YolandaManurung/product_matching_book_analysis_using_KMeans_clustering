# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import re
import gensim
from gensim.models import Word2Vec
import numpy as np
from scipy import linalg

# %%
data = pd.read_csv("./all_data.csv")
data.head()
# Out:
#                   book_title                       Book_series  \
# 0  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 1  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 2  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 3  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 4  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
#
#                                      book_series_url  \
# 0  https://www.goodreads.com/series/104014-a-cour...
# 1  https://www.goodreads.com/series/104014-a-cour...
# 2  https://www.goodreads.com/series/104014-a-cour...
# 3  https://www.goodreads.com/series/104014-a-cour...
# 4  https://www.goodreads.com/series/104014-a-cour...
#
#                                           book_image  \
# 0  https://images.gr-assets.com/books/1485528243l...
# 1  https://images.gr-assets.com/books/1485528243l...
# 2  https://images.gr-assets.com/books/1485528243l...
# 3  https://images.gr-assets.com/books/1485528243l...
# 4  https://images.gr-assets.com/books/1485528243l...
#
#                                       book_image_url  book_rating  \
# 0  https://www.goodreads.com/book/photo/23766634-...         4.51
# 1  https://www.goodreads.com/book/photo/23766634-...         4.51
# 2  https://www.goodreads.com/book/photo/23766634-...         4.51
# 3  https://www.goodreads.com/book/photo/23766634-...         4.51
# 4  https://www.goodreads.com/book/photo/23766634-...         4.51
#
#      book_author                                         author_url  \
# 0  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 1  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 2  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 3  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 4  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
#
#                                       genre                 reviewer_name  \
# 0  Fantasy, Romance, Young Adult, New Adult                          emma
# 1  Fantasy, Romance, Young Adult, New Adult  Em (RunawayWithDreamthieves)
# 2  Fantasy, Romance, Young Adult, New Adult     Cait • A Page with a View
# 3  Fantasy, Romance, Young Adult, New Adult                Natalie Monroe
# 4  Fantasy, Romance, Young Adult, New Adult                     Emily May
#
#                                         reviewer_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                       reviewer_image  \
# 0  https://images.gr-assets.com/users/1520568130p...
# 1  https://images.gr-assets.com/users/1538507799p...
# 2  https://images.gr-assets.com/users/1523134490p...
# 3  https://images.gr-assets.com/users/1339730817p...
# 4  https://images.gr-assets.com/users/1528390751p...
#
#                                   reviewer_image_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                               review  ID
# 0  202.\r\nThat’s the number of times that the wo...   1
# 1  I need a black silk robe and a balcony to wear...   2
# 2  THIS BOOK TOTALLY WRECKED ME. In the best poss...   3
# 3  3.75 stars\r\n"Rhys stepped off the stairs and...   4
# 4  I wish so much that I could tell you I loved t...   5

# %% [markdown]
# # Data Preprocessing

# %%
data.isnull().sum()
# Out:
# book_title                0
# Book_series           12779
# book_series_url       12779
# book_image                2
# book_image_url            2
# book_rating               0
# book_author               0
# author_url                0
# genre                   121
# reviewer_name            25
# reviewer_url             25
# reviewer_image           25
# reviewer_image_url       25
# review                  742
# ID                        0
# dtype: int64

# %%
data.dtypes
# Out:
# book_title             object
# Book_series            object
# book_series_url        object
# book_image             object
# book_image_url         object
# book_rating           float64
# book_author            object
# author_url             object
# genre                  object
# reviewer_name          object
# reviewer_url           object
# reviewer_image         object
# reviewer_image_url     object
# review                 object
# ID                      int64
# dtype: object

# %%
data['Book_series'] = data['Book_series'].fillna(data['Book_series'].mode().iloc[0])
data['book_series_url'] = data['book_series_url'].fillna(data['book_series_url'].mode().iloc[0])
data['book_image'] = data['book_image'].fillna(data['book_image'].mode().iloc[0])
data['book_image_url'] = data['book_image_url'].fillna(data['book_image_url'].mode().iloc[0])
data['genre'] = data['genre'].fillna(data['genre'].mode().iloc[0])
data['reviewer_name'] = data['reviewer_name'].fillna(data['reviewer_name'].mode().iloc[0])
data['reviewer_url'] = data['reviewer_url'].fillna(data['reviewer_url'].mode().iloc[0])
data['reviewer_image'] = data['reviewer_image'].fillna(data['reviewer_image'].mode().iloc[0])
data['reviewer_image_url'] = data['reviewer_image_url'].fillna(data['reviewer_image_url'].mode().iloc[0])
data['review'] = data['review'].fillna(data['review'].mode().iloc[0])

# %%
data.isnull().sum()
# Out:
# book_title            0
# Book_series           0
# book_series_url       0
# book_image            0
# book_image_url        0
# book_rating           0
# book_author           0
# author_url            0
# genre                 0
# reviewer_name         0
# reviewer_url          0
# reviewer_image        0
# reviewer_image_url    0
# review                0
# ID                    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['book_title'].duplicated().sum()
# Out:
# 20837

# %%
data['book_title'].drop_duplicates(keep=False,inplace=True)
data.head()
# Out:
#                   book_title                       Book_series  \
# 0  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 1  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 2  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 3  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 4  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
#
#                                      book_series_url  \
# 0  https://www.goodreads.com/series/104014-a-cour...
# 1  https://www.goodreads.com/series/104014-a-cour...
# 2  https://www.goodreads.com/series/104014-a-cour...
# 3  https://www.goodreads.com/series/104014-a-cour...
# 4  https://www.goodreads.com/series/104014-a-cour...
#
#                                           book_image  \
# 0  https://images.gr-assets.com/books/1485528243l...
# 1  https://images.gr-assets.com/books/1485528243l...
# 2  https://images.gr-assets.com/books/1485528243l...
# 3  https://images.gr-assets.com/books/1485528243l...
# 4  https://images.gr-assets.com/books/1485528243l...
#
#                                       book_image_url  book_rating  \
# 0  https://www.goodreads.com/book/photo/23766634-...         4.51
# 1  https://www.goodreads.com/book/photo/23766634-...         4.51
# 2  https://www.goodreads.com/book/photo/23766634-...         4.51
# 3  https://www.goodreads.com/book/photo/23766634-...         4.51
# 4  https://www.goodreads.com/book/photo/23766634-...         4.51
#
#      book_author                                         author_url  \
# 0  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 1  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 2  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 3  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 4  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
#
#                                       genre                 reviewer_name  \
# 0  Fantasy, Romance, Young Adult, New Adult                          emma
# 1  Fantasy, Romance, Young Adult, New Adult  Em (RunawayWithDreamthieves)
# 2  Fantasy, Romance, Young Adult, New Adult     Cait • A Page with a View
# 3  Fantasy, Romance, Young Adult, New Adult                Natalie Monroe
# 4  Fantasy, Romance, Young Adult, New Adult                     Emily May
#
#                                         reviewer_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                       reviewer_image  \
# 0  https://images.gr-assets.com/users/1520568130p...
# 1  https://images.gr-assets.com/users/1538507799p...
# 2  https://images.gr-assets.com/users/1523134490p...
# 3  https://images.gr-assets.com/users/1339730817p...
# 4  https://images.gr-assets.com/users/1528390751p...
#
#                                   reviewer_image_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                               review  ID
# 0  202.\r\nThat’s the number of times that the wo...   1
# 1  I need a black silk robe and a balcony to wear...   2
# 2  THIS BOOK TOTALLY WRECKED ME. In the best poss...   3
# 3  3.75 stars\r\n"Rhys stepped off the stairs and...   4
# 4  I wish so much that I could tell you I loved t...   5

# %%
data["book_rating"]= data["book_rating"].astype(str)

# %%
data['book_title'] = data['book_title'].replace('[^a-zA-Z ]', ' ', regex=True)
data['review'] = data['review'].replace('[^a-zA-Z0-9 ]', ' ', regex=True)

# %%
data = data[['book_title', 'review', 'book_rating']]
data = data[pd.notnull(data['review'])]
data.sample(60)
# Out:
#                                               book_title  \
# 20899           I Can t Breathe  A Killing on Bay Street
# 1951                     Hum If You Don t Know the Words
# 10035                                    The Waking Land
# 9996                                             Fallout
# 2042                                 Gwendy s Button Box
# 12538                               The Unbreakable Code
# 6921                                               Trust
# 1126                                   The Orphan s Tale
# 9913                                               Wired
# 322                                      Norse Mythology
# 1442                          The Chilbury Ladies  Choir
# 15295                                The Stolen Marriage
# 5074                                                Blur
# 8591                                            Off Base
# 8796                                     The Fifth Petal
# 456                                            Exit West
# 17856                                         Bannerless
# 9156                                      Sulfur Springs
# 9295                                         Buy Me  Sir
# 12640                              Days at Bleakly Manor
# 11278  World Without Mind  The Existential Threat of ...
# 15971                                      Akata Warrior
# 8019   From Here to Eternity  Traveling the World to ...
# 8838                                     Dangerous Minds
# 20228                                Out of the Ordinary
# 6272                                      The House Mate
# 5700                                    Lost In Scotland
# 8401                                                Less
# 10857            The Legend of Korra  Turf Wars Part One
# 11126
# 20289                             Caged  Savage Men
# 17532                                  The Good Daughter
# 18436                                          Bad Penny
# 8199                                     The Nowhere Man
# 11053                                        Fault Lines
# 2053                                 Gwendy s Button Box
# 4160                                  The Rules of Magic
# 5369                                            Reunited
# 3640                                       Say I m Yours
# 19961                                          Colorless
# 9198                                      Catching Carly
# 15081                                   Point of Contact
# 13209                                Painted On My Heart
# 18299                                  The Drowned Girls
# 13104                           The Deep Dark Descending
# 17083                            Prison Planet Barbarian
# 15461                                          Void Star
# 10406                                Where Dead Men Meet
# 3957                                       Camino Island
# 2611                             Accidentally on Purpose
# 4957                          Eight Days on Planet Earth
# 8331                                   The Clover Chapel
# 4483                                         Flight Risk
# 19318                                         Matchmaker
# 10214                                    Matilda Empress
# 6465                               The Collapsing Empire
# 1734                                   The Roanoke Girls
# 7291                                       The Two of Us
# 15288                                      Two Days Gone
# 11050                                        Fault Lines
#
#                                                   review book_rating
# 20899   Try to imagine a world where there isn t a va...        4.37
# 1951   3 5 Stars   Since June the 16th when South Afr...        4.22
# 10035  Filled with magic  dueling lands  and a contin...        3.38
# 9996   This book takes the detective to Kansas  The r...        3.96
# 2042   Click here to watch a video review of this boo...         3.9
# 12538  So if you ve read my review on the first book ...        4.24
# 6921   Title  Trust  Series  Standalone  Author  Kyli...        4.08
# 1126   Noa was thrown out of her parents  home becaus...        4.01
# 9913   Julie Garwood used to be one of my go to autho...        3.78
# 322                                                  ...         4.1
# 1442    The Chilbury Ladies  Choir  is an epistolary ...        3.99
# 15295  5              WONDERFUL ENGROSSING UNPUTDOWNA...        4.23
# 5074   Wow   Ever since reading the previous books in...        4.38
# 8591   3 5 Stars   I liked this one fine  But it didn...        3.95
# 8796   Actual Rating 2 5  Hmm   this book is pretty h...        3.66
# 456    2 5 stars  What started out to be a gorgeously...        3.81
# 17856  I really liked this so I guess it is three and...         3.7
# 9156   Cork the main protagonist lost his wife and fa...        3.99
# 9295   It s LIVE    99c and FREE on KU    AMAZON US  ...        3.99
# 12640  Ok  I LOVE Bleak House by Charles Dickens  as ...        3.84
# 11278  Silicon Valley dreams of merging mind and mach...        3.64
# 15971  A warrior s journey continues     5 5 Review t...        4.27
# 8019   My anticipated reaction   My actual reaction  ...        4.28
# 8838   4 5 Giggle Me Silly Stars  There is just somet...        3.58
# 20228  Full review and q a on Faithfully Bookish  Tur...        4.19
# 6272   4  Look  but don t touch  stars  Max Alexander...        3.88
# 5700   4 5 Stars   Hilaria Alexander delivers a sweet...        3.83
# 8401   4ish stars   Such a clever book  For the first...        3.83
# 10857  BEAUITFUL  SO FUCKING BEAUTIFUL  RTC     IT IS...        4.28
# 11126  I ve read the book  Die Ermordung des Commenda...        4.08
# 20289  2 5 stars  IDK why I keep reading Clarissa Wil...        3.76
# 17532  ARC for review   expected publication date  Fe...        3.31
# 18436  FOUR LOVE ME STARS    I didn t do serious or p...        4.17
# 8199   He became the protector of the innocent  the w...         4.1
# 11053  fault line  noun  1  a line on a rock surface ...        3.92
# 2053   What a fantastic book  It s stories like this ...         3.9
# 4160   Traveling Sisters review by Brenda with Norma ...        3.98
# 5369   I m rating this book 2 stars because it was ju...        3.83
# 3640   4 I Am Tired Of Waiting Around For You  Stars ...        4.12
# 19961  Hi    Thank you for checking out Colorless  Th...        3.59
# 9198   Loved this romantic comedy  Full review to com...        4.03
# 15081  Classic Clancy characters in the political thr...        3.95
# 13209  5 Brush Stroke Stars  Some facts in evidence  ...        4.24
# 18299  Advanced Reader Copy  ARC  provided by the Aut...        4.22
# 13104  4 0 Stars Video Review  https   youtu be VPZdR...        3.93
# 17083  This was a pretty good spin off but biting my ...        4.01
# 15461  This will be an odd review  because I m going ...        3.68
# 10406  Luke Hamilton  a junior officer at the British...        3.75
# 3957   Very disappointed in this book  Doesn t come c...        3.73
# 2611   The third book in the Heartbreaker Bay series ...        4.05
# 4957   This book was really cute  and quite unexpecte...        3.71
# 8331   I am super picky about second chance romance s...        4.17
# 4483   Well   that s a quickie  if I ever read one  A...        3.72
# 19318  This is such a refreshingly clean Christian ro...        4.26
# 10214  This review has been hidden because it contain...        3.52
# 6465   The beginning of the end of a thousand years o...        4.09
# 1734   These characters enraged me at times  the stor...        3.72
# 7291   The Two of Us by Victoria Bylin was a read tha...        4.12
# 15288  Every writer of fiction confronts the problem ...        3.75
# 11050  I m not sure what it is about second chances a...        3.92

# %%
data.shape
# Out:
# (21559, 3)

# %%
data.isnull().sum()
# Out:
# book_title     0
# review         0
# book_rating    0
# dtype: int64

# %%
data.index = range(21559)
data['review'].apply(lambda x: len(x.split(' '))).sum()
# Out:
# 7593022

# %%
def print_review(index):
    example = data[data.index == index][['review', 'book_title']].values[0]
    if len(example) > 0:
        print('Review:\n', example[0])
        print('\nBook Title:\n', example[1])
        
print_review(12)
# Out:
# Review:
#  When the book you re highly anticipating has no cover  no title  and no synopsis   And a May 2017 release date
#
# Book Title:
#  A Court of Wings and Ruin

# %%
print_review(25)
# Out:
# Review:
#  FULL REVIEW POSTED  If you re reading this  please be warned that you re in for one hell of a rant  There will be quite a lot of swearing and some minor spoilers   Major spoilers will be marked   Also  if you liked this book and have a problem with me trashing everything you ve ever loved  you may want to turn back now      I m giving you one more chance  This is actually the worst book rant I ve ever written      No  You really want to read this review   Move right the fuck along  then  Don t say I didn t warn you   You know when you re at the beach on a really nice summer day  and the sand is all nice and soft and the sun is warm but not too hot and you walk down to the edge of the water for what you just know is going to be a gloriously refreshing swim in the ocean       so you start wading in  and it seems fine at first  and then all of a sudden your foot comes down in the middle of a massive swath of slimy  smelly  warm seaweed aND YOU TRY TO STEP BACK OUT BUT SUDDENLY IT S EVERYWHERE AND IT S AWFUL AND YOUR DAY GOES TO SHIT  THAT is what reading this book felt like   Buuuut before I get started with the rant  let s just get this out of the way and discuss the only thing I actually liked  Lucien   I remember thinking Lucien was just okay in ACOTAR and ACOMAF  Everyone seems to love him  but I was always kind of indifferent towards him  Surprisingly  he was the only character who had actual development in this book  and I ended up liking him way more than I expected to  Getting to see the Autumn Court and learning more about his family and history made him finally feel like a fully fleshed out character  rather than just Tamlin s mediocre sidekick  I still don t really give a shit about him and Elain  but his friendship with Feyre was lovely  I feel like male female friendships that are truly platonic are so hard to come by in YA books  and it was so great to see the two of them overcome the anger and guilt that had grown between them in previous books  Unfortunately  Lucien ends up going off on some random ass irrelevant mission for half the book  leaving me stuck with one of the dullest groups of characters I ve read about in a while   sigh   Now that that s over  the rest of this review is basically gonna be a list of all the stuff I hated  which was  everything else  tbh  This is super unorganized and in no particular order   The Spring Court  Alright  the Spring Court was boring and annoying in books 1 and 2  so I wasn t really looking forward to being back there  I thought things would have least been a little more interesting with Feyre 2 0 back to fuck shit up  but all I got was some half assed Cersei wannabe who was so hell bent on her personal revenge plot that she gave zero fucks about the consequences and hypocrisy of her actions   The one dimensional villain  This was one of my biggest issues with this book  There is absolutely NO moral gray area  every aspect of the war is as black and white as a fucking dalmatian  Why exactly does Hybern want to invade Prythian and take down the wall separating the human realm         Literally all we are told  over and over again  is that Hybern is ruthless and vicious and evil and BLAH BLAH BLAH I DON T CARE  I can accept Amarantha being a sadistic psychopath with little complexity  but even she had her reasons for what she did  In this book ALL of the people from Hybern are universally evil demonic asshats  and as I refuse to believe that an entire nation is composed only of murderous psychopaths  I call bullshit  There s a bunch of infodump about how the king has somehow brainwashed his whole population into supporting the war     but I don t fucking buy it  If the people of Hybern were the least impacted by the treaty that split the other territories  as we are explicitly told   why would they be the most opposed to it  I personally LOVE politics  and the political aspect of worldbuilding is always one of my favorite parts of reading high fantasy  ummmm news flash  cou ...
#
# Book Title:
#  A Court of Wings and Ruin

# %% [markdown]
# # 3. Features Extraction

# %%
import nltk
from gensim.models import doc2vec
from gensim.models import Word2Vec
import logging

from gensim.models.doc2vec import (
    Doc2Vec,
    TaggedDocument,
)

# %%
import nltk
tokens = []
def tokenize_text(text):
    for sent in nltk.sent_tokenize(text):
        for word in nltk.word_tokenize(sent):
            if len(word) < 2:
                continue
            tokens.append(word.lower())
    return tokens
review = data.apply(
    lambda r: TaggedDocument(words=tokenize_text(r['review']), tags=[r.book_title]), axis=1)

# %%
print("Review:\n", tokens[30])
# Out:
# Review:
#  statistic

# %%
import multiprocessing
import socket
from tqdm import tqdm
cores = multiprocessing.cpu_count()

# %%
model_review = Doc2Vec(dm=0, vector_size=300, negative=5, hs=0, min_count=2, sample = 0, workers=cores)
model_review.build_vocab([x for x in tqdm(review)])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 21559/21559 [00:01<00:00, 19144.87it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-c748c6e8a11c> in <module>
#       1 model_review = Doc2Vec(dm=0, vector_size=300, negative=5, hs=0, min_count=2, sample = 0, workers=cores)
# ----> 2 model_review.build_vocab([x for x in tqdm(review)])
#
# ~\Anaconda3\lib\site-packages\gensim\models\doc2vec.py in build_vocab(self, documents, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     926         total_words, corpus_count = self.vocabulary.scan_vocab(
#     927             documents=documents, corpus_file=corpus_file, docvecs=self.docvecs,
# --> 928             progress_per=progress_per, trim_rule=trim_rule
#     929         )
#     930         self.corpus_count = corpus_count
#
# ~\Anaconda3\lib\site-packages\gensim\models\doc2vec.py in scan_vocab(self, documents, corpus_file, docvecs, progress_per, trim_rule)
#    1123             documents = TaggedLineDocument(corpus_file)
#    1124
# -> 1125         total_words, corpus_count = self._scan_vocab(documents, docvecs, progress_per, trim_rule)
#    1126
#    1127         logger.info(
#
# ~\Anaconda3\lib\site-packages\gensim\models\doc2vec.py in _scan_vocab(self, documents, docvecs, progress_per, trim_rule)
#    1073
#    1074             for word in document.words:
# -> 1075                 vocab[word] += 1
#    1076             total_words += len(document.words)
#    1077
#
# KeyboardInterrupt:

# %%
len(model_review.docvecs)

# %%
model_review.wv.vocab.keys()

# %%
model_review.most_similar('spoilers')
